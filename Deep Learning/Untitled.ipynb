# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./datasets/imbalance_data_CIC-IDS-2017 Dataset.csv')

# %%
df
# Out:
#          Unnamed: 0  flow_duration  total_fwd_packets  total_backward_packets  \
# 0                 0            3.0                2.0                     0.0
# 1                 1          109.0                1.0                     1.0
# 2                 2           52.0                1.0                     1.0
# 3                 3           34.0                1.0                     1.0
# 4                 4            3.0                2.0                     0.0
# ...             ...            ...                ...                     ...
# 2829171     3119333        32215.0                4.0                     2.0
# 2829172     3119334          324.0                2.0                     2.0
# 2829173     3119335           82.0                2.0                     1.0
# 2829174     3119336      1048635.0                6.0                     2.0
# 2829175     3119337        94939.0                4.0                     2.0
#
# ...
